# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import numpy as np

import re
import os
import string
import operator
from itertools import islice
from collections import Counter

from datetime import date
import matplotlib.dates as dates

from nltk import ngrams
import nltk as nltk
from nltk.corpus import stopwords

# %%
sns.set_style('darkgrid')
sns.set_context('paper')
pd.set_option('display.max_colwidth', None)

# %%
punct_signs = list(string.punctuation)
punct_signs.append('…')
punct_signs.append('¿')
punct_signs.append('•')
punct_signs.append('”')
punct_signs.append('“')
punct_signs.append('–')
punct_signs.remove('&')
punct_signs.append('∑')

stop_words = stopwords.words('english') + ['also', 'could', ]

# %%
import math
def clean_text(text):
    for p in punct_signs:
        text = text.replace(p, ' ')
    clean_text = text.lower().split()
    clean_text = [w for w in clean_text if w not in stop_words]
    return clean_text

# %% [markdown]
# ## 50 most frequently used ngrams in description

# %%
#m is the number of top ngrams.
def getNGrams(text, n, m):
    h_dict = {}   
    ngramas = list(ngrams(text, n))
    for grams in ngramas:
        words = ' '.join(grams).strip()
        if words not in h_dict:
            h_dict[words] = 0
        h_dict[words] = h_dict[words] + 1
        
    sorted_dict = sorted(h_dict.items(), key=operator.itemgetter(1), reverse=True)
    top_values = list(islice(sorted_dict, m))
    return [(r[0], r[1], round(r[1]/len(ngramas)*100,2)) for r in top_values]

def printNgrams(data, m):
    Ngrams = []
    unigrams = getNGrams(data, 1, m)
    bigrams = getNGrams(data, 2 , m)
    trigrams = getNGrams(data, 3 , m)
    for i in range(0,m):
        Ngrams.append(unigrams[i] + bigrams[i] + trigrams[i])
    df = pd.DataFrame(Ngrams, columns=['Unigrams', 'Absolute Freq', 'Relative Freq', 
                                       'Bigrams', 'Absolute Freq', 'Relative Freq', 
                                       'Trigrams', 'Absolute Freq', 'Relative Freq',]) 
    return df

# %%
df = df.fillna('')
data = #ADD_YOUR_TEXT as String e.g "This is my text"
data  = clean_text(data)

# %%
dfNgrams = printNgrams(data, 50)
dfNgrams
# Out:
#          Unigrams  Absolute Freq  Relative Freq                  Bigrams  \
# 0          course            330           1.43       science technology
# 1            data            294           1.27         machine learning
# 2        students            289           1.25         computer science
# 3      technology            257           1.11  artificial intelligence
# 4         science            247           1.07           topics include
# 5          social            226           0.98             data science
# 6     engineering            180           0.78         security privacy
# 7        computer            177           0.77             case studies
# 8         systems            175           0.76            public policy
# 9          issues            168           0.73          decision making
# 10         design            165           0.71    intellectual property
# 11        ethical            148           0.64     computer engineering
# 12        society            143           0.62       technology society
# 13         policy            141           0.61          social sciences
# 14         topics            135           0.58            data analysis
# 15       security            135           0.58           ethical issues
# 16        privacy            131           0.57               real world
# 17    information            126           0.55                 big data
# 18          human            124           0.54                      e g
# 19       learning            117           0.51           students learn
# 20       research            110           0.48           social science
# 21             ai            103           0.45            social issues
# 22   technologies            102           0.44           issues related
# 23         ethics            102           0.44          problem solving
# 24        include            100           0.43               wide range
# 25      computing             86           0.37   information technology
# 26         public             81           0.35       introduce students
# 27      including             76           0.33           data analytics
# 28        studies             75           0.32          intelligence ai
# 29       software             75           0.32          course students
# 30        machine             74           0.32            human factors
# 31       analysis             73           0.32          course provides
# 32   applications             70           0.30      electrical computer
# 33         skills             68           0.29      introduces students
# 34   intelligence             67           0.29           topics covered
# 35    development             66           0.29            legal ethical
# 36         impact             66           0.29           human centered
# 37     challenges             63           0.27          centered design
# 38            new             63           0.27              data driven
# 39       concepts             63           0.27            policy issues
# 40      knowledge             62           0.27           climate change
# 41       problems             62           0.27          course examines
# 42     techniques             61           0.26           human computer
# 43     artificial             61           0.26              course aims
# 44  understanding             58           0.25             social media
# 45           well             58           0.25     software engineering
# 46        methods             57           0.25         social political
# 47          world             55           0.24        technology policy
# 48      technical             55           0.24      science engineering
# 49           work             55           0.24      professional ethics
#
#     Absolute Freq  Relative Freq                            Trigrams  \
# 0              68           0.29          artificial intelligence ai
# 1              65           0.28     electrical computer engineering
# 2              55           0.24          science technology studies
# 3              55           0.24               human centered design
# 4              46           0.20          human computer interaction
# 5              44           0.19          science technology society
# 6              39           0.17             obtain hands experience
# 7              38           0.16          humanities social sciences
# 8              34           0.15         science technology medicine
# 9              29           0.13           participants obtain hands
# 10             29           0.13                public policy issues
# 11             29           0.13                   face face classes
# 12             23           0.10               machine learning data
# 13             23           0.10          course introduces students
# 14             20           0.09        course provides introduction
# 15             20           0.09                legal ethical issues
# 16             19           0.08             ai robotic technologies
# 17             19           0.08                    large scale data
# 18             18           0.08              topics covered include
# 19             18           0.08        information security privacy
# 20             17           0.07         centered design engineering
# 21             17           0.07               emphasis written oral
# 22             16           0.07                learning data mining
# 23             16           0.07           course introduce students
# 24             15           0.06   individuals organizations society
# 25             15           0.06         engineering applications ai
# 26             15           0.06   reasoning probabilistic reasoning
# 27             14           0.06            hands experience project
# 28             14           0.06      experience project assignments
# 29             14           0.06         project assignments utilize
# 30             13           0.06        assignments utilize publicly
# 31             13           0.06          utilize publicly available
# 32             13           0.06         publicly available datasets
# 33             13           0.06    supervised unsupervised learning
# 34             12           0.05                  using case studies
# 35             12           0.05                     real world data
# 36             12           0.05                   wide range topics
# 37             12           0.05        robotic technologies rapidly
# 38             11           0.05     technologies rapidly developing
# 39             11           0.05        rapidly developing spreading
# 40             11           0.05  developing spreading corresponding
# 41             11           0.05      spreading corresponding social
# 42             11           0.05          corresponding social human
# 43             11           0.05                social human impacts
# 44             10           0.04                data systems society
# 45             10           0.04            approved academic credit
# 46             10           0.04                  credit subject may
# 47             10           0.04                    subject may used
# 48             10           0.04                     may used degree
# 49             10           0.04                 used degree granted
#
#     Absolute Freq  Relative Freq
# 0              14           0.06
# 1              13           0.06
# 2              10           0.04
# 3              10           0.04
# 4              10           0.04
# 5               9           0.04
# 6               7           0.03
# 7               7           0.03
# 8               7           0.03
# 9               6           0.03
# 10              6           0.03
# 11              6           0.03
# 12              6           0.03
# 13              6           0.03
# 14              6           0.03
# 15              6           0.03
# 16              5           0.02
# 17              5           0.02
# 18              5           0.02
# 19              5           0.02
# 20              5           0.02
# 21              5           0.02
# 22              5           0.02
# 23              5           0.02
# 24              5           0.02
# 25              4           0.02
# 26              4           0.02
# 27              4           0.02
# 28              4           0.02
# 29              4           0.02
# 30              4           0.02
# 31              4           0.02
# 32              4           0.02
# 33              4           0.02
# 34              4           0.02
# 35              4           0.02
# 36              4           0.02
# 37              4           0.02
# 38              4           0.02
# 39              4           0.02
# 40              4           0.02
# 41              4           0.02
# 42              4           0.02
# 43              4           0.02
# 44              4           0.02
# 45              4           0.02
# 46              4           0.02
# 47              4           0.02
# 48              4           0.02
# 49              4           0.02

# %% [markdown]
# ## 30 Most used verbs and adjectives in description

# %%
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
from nltk.stem import WordNetLemmatizer
wordnet_lemmatizer = WordNetLemmatizer()
nltk.download('wordnet');
# Out:
# [nltk_data] Downloading package punkt to /home/yadira/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/yadira/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to /home/yadira/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
#m is the number of top ngrams.
def getNPartsOfSpeech(text, m, tag):
    h_dict = {}   
    tokens = nltk.word_tokenize(text)
    pos_tags = nltk.pos_tag(tokens)
    #lemmatization and filtering allowed tags
    filtered_tags = [wordnet_lemmatizer.lemmatize(pt[0], pos="v") for pt in pos_tags if pt[1].startswith(tag)]
    
    for ft in filtered_tags:    
        if ft not in h_dict:
            h_dict[ft] = 0
        h_dict[ft] += 1
        
    sorted_dict = sorted(h_dict.items(), key=operator.itemgetter(1), reverse=True)
    top_values = list(islice(sorted_dict, m))
    return [(r[0], r[1], round(r[1]/len(filtered_tags)*100,2)) for r in top_values]

def printNPOS(data, m):
    postags = []
    
    verbs = getNPartsOfSpeech(data, m, 'V')
    verbs += [(None, None)] * (m - len(verbs))
    
    adjs = getNPartsOfSpeech(data, m , 'J')
    adjs +=[(None, None)] * (m - len(adjs))
    
    nouns = getNPartsOfSpeech(data, m , 'N')
    nouns +=[(None, None)] * (m - len(nouns))
    
    for i in range(0,m):
        if all(verbs[i]) or all(adj[i]) or all(nouns[i]):
            postags.append(verbs[i] + adjs[i] + nouns[i])
    df = pd.DataFrame(postags, columns=['Verbs', 'Absolute Freq', 'Relative Freq', 
                                       'Adjectives', 'Absolute Freq', 'Relative Freq',
                                        'Nouns', 'Absolute Freq', 'Relative Freq' ]) 
    return df

# %%
data = ' '.join(list(df['CourseDescription']))

# %%
printNPOS(data, 30)
# Out:
#          Verbs  Absolute Freq  Relative Freq         Adjectives  \
# 0           be            635          14.44             social
# 1      include            183           4.16            ethical
# 2         have            140           3.18               such
# 3          use            101           2.30              human
# 4      provide             93           2.11             public
# 5        learn             69           1.57                new
# 6      develop             61           1.39          technical
# 7      explore             58           1.32              legal
# 8      compute             57           1.30         artificial
# 9    introduce             47           1.07         scientific
# 10  understand             47           1.07       professional
# 11       focus             46           1.05      technological
# 12     examine             43           0.98           societal
# 13       apply             40           0.91              other
# 14      relate             40           0.91            digital
# 15      design             40           0.91          political
# 16       cover             36           0.82      environmental
# 17     address             36           0.82          different
# 18          do             34           0.77            current
# 19     present             32           0.73             global
# 20     analyze             32           0.73       intellectual
# 21      emerge             32           0.73  interdisciplinary
# 22        work             30           0.68           economic
# 23        make             30           0.68              basic
# 24     discuss             29           0.66          practical
# 25       write             28           0.64      computational
# 26        take             27           0.61            various
# 27       shape             27           0.61         historical
# 28     require             26           0.59               many
# 29       teach             24           0.55            complex
#
#     Absolute Freq  Relative Freq         Nouns  Absolute Freq  Relative Freq
# 0             216           4.85        course            344           2.45
# 1             136           3.05          data            252           1.79
# 2              91           2.04    technology            231           1.64
# 3              89           2.00      students            212           1.51
# 4              74           1.66       science            202           1.44
# 5              60           1.35         issue            173           1.23
# 6              52           1.17      engineer            169           1.20
# 7              51           1.14       systems            167           1.19
# 8              48           1.08        design            155           1.10
# 9              48           1.08       society            131           0.93
# 10             48           1.08      computer            131           0.93
# 11             47           1.05        policy            127           0.90
# 12             44           0.99       privacy            121           0.86
# 13             44           0.99   information            118           0.84
# 14             41           0.92      security            116           0.82
# 15             38           0.85      research            105           0.75
# 16             37           0.83  technologies            100           0.71
# 17             36           0.81            AI             98           0.70
# 18             36           0.81         study             98           0.70
# 19             35           0.79        ethics             94           0.67
# 20             34           0.76       project             87           0.62
# 21             32           0.72        impact             80           0.57
# 22             32           0.72        topics             79           0.56
# 23             30           0.67         learn             75           0.53
# 24             30           0.67      Students             72           0.51
# 25             30           0.67       machine             71           0.50
# 26             29           0.65         model             70           0.50
# 27             28           0.63      analysis             69           0.49
# 28             27           0.61      software             67           0.48
# 29             27           0.61  applications             66           0.47
